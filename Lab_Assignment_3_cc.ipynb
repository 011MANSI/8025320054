# %% [markdown]
# <a href="https://colab.research.google.com/github/011MANSI/8025320054/blob/main/Lab_Assignment_3_cc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ***Mansi - 8025320054***
# ***Assignment 3***

# %%
# Part I: Randomized Sales Data Generation (NumPy)

# %%
# 1. Initialize Random Seed

import numpy as np

roll_number = 8025320054
valid_seed = roll_number % (2**32)

rng = np.random.default_rng(valid_seed)

sales_data = rng.integers(1000, 5000, size=(12, 4))

print(sales_data)
# Out:
# [[3401 2333 1208 1191]
#  [1154 2244 4717 3859]
#  [3100 1995 3680 2778]
#  [1709 3957 3655 1562]
#  [4933 1462 4908 4958]
#  [4615 4393 3782 3118]
#  [1195 3807 1533 3292]
#  [4963 2559 1270 4608]
#  [1924 4074 3237 2470]
#  [4165 3746 2777 4533]
#  [4472 2898 4898 1558]
#  [2339 4654 1728 1527]]

# %%
# 2. Generate Sales Data (12 × 4)

# Generate random sales data between 1000 and 5000
sales_data = np.random.randint(1000, 5000, size=(12, 4))

sales_data
# Out:
# array([[4870, 2729, 4852, 1614],
#        [3669, 3432, 2649, 2490],
#        [4108, 3349, 4290, 4102],
#        [1075, 3188, 3564, 1997],
#        [2366, 2751, 2924, 1395],
#        [3252, 1255, 4295, 1215],
#        [4164, 1538, 2918, 4402],
#        [3444, 3847, 3223, 1934],
#        [2595, 4691, 2998, 2752],
#        [4767, 2659, 1849, 3593],
#        [4708, 1395, 2091, 4822],
#        [2657, 2268, 2075, 3516]])

# %%
# 3. Convert to DataFrame

import pandas as pd

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

columns = ["Electronics", "Clothing", "Home & Kitchen", "Sports"]

df = pd.DataFrame(sales_data, columns=columns, index=months)

df
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         4870      2729            4852    1614
# Feb         3669      3432            2649    2490
# Mar         4108      3349            4290    4102
# Apr         1075      3188            3564    1997
# May         2366      2751            2924    1395
# Jun         3252      1255            4295    1215
# Jul         4164      1538            2918    4402
# Aug         3444      3847            3223    1934
# Sep         2595      4691            2998    2752
# Oct         4767      2659            1849    3593
# Nov         4708      1395            2091    4822
# Dec         2657      2268            2075    3516

# %%
# Part II: Data Manipulation and Analysis (Pandas)

# %%
# 1. First 5 Rows & Summary Statistics

df.head()
df.describe()
# Out:
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   3472.916667  2758.500000     3144.000000  2819.333333
# std    1149.413563  1034.268868      955.007568  1238.515485
# min    1075.000000  1255.000000     1849.000000  1215.000000
# 25%    2641.500000  2085.500000     2509.500000  1854.000000
# 50%    3556.500000  2740.000000     2961.000000  2621.000000
# 75%    4300.000000  3369.750000     3745.500000  3720.250000
# max    4870.000000  4691.000000     4852.000000  4822.000000

# %%
# 2. Total Sales per Category & per Month

# Total per category
total_per_category = df.sum()
print("Total Sales per Category:\n", total_per_category)

# Total per month
total_per_month = df.sum(axis=1)
print("\nTotal Sales per Month:\n", total_per_month)
# Out:
# Total Sales per Category:
#  Electronics       41675
# Clothing          33102
# Home & Kitchen    37728
# Sports            33832
# dtype: int64
#
# Total Sales per Month:
#  Jan    14065
# Feb    12240
# Mar    15849
# Apr     9824
# May     9436
# Jun    10017
# Jul    13022
# Aug    12448
# Sep    13036
# Oct    12868
# Nov    13016
# Dec    10516
# dtype: int64

# %%
# 3. Average Sales Growth Between Consecutive Months

growth = df.pct_change()

avg_growth = growth.mean() * 100
print("Average Growth Rate (%):\n", avg_growth)
# Out:
# Average Growth Rate (%):
#  Electronics        8.728347
# Clothing          10.617514
# Home & Kitchen    -2.367316
# Sports            28.260439
# dtype: float64

# %%
# 4. Add Total Sales & Growth Rate Columns

df["Total Sales"] = df.sum(axis=1)

df["Growth Rate"] = df["Total Sales"].pct_change() * 100

df
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         4870      2729            4852    1614        14065          NaN
# Feb         3669      3432            2649    2490        12240   -12.975471
# Mar         4108      3349            4290    4102        15849    29.485294
# Apr         1075      3188            3564    1997         9824   -38.015017
# May         2366      2751            2924    1395         9436    -3.949511
# Jun         3252      1255            4295    1215        10017     6.157270
# Jul         4164      1538            2918    4402        13022    29.999002
# Aug         3444      3847            3223    1934        12448    -4.407925
# Sep         2595      4691            2998    2752        13036     4.723650
# Oct         4767      2659            1849    3593        12868    -1.288739
# Nov         4708      1395            2091    4822        13016     1.150140
# Dec         2657      2268            2075    3516        10516   -19.207130

# %%
# 5. Apply Randomized Discount

if roll_number % 2 == 0:
    df["Electronics"] = df["Electronics"] * 0.9
    print("10% Discount Applied to Electronics")
else:
    df["Clothing"] = df["Clothing"] * 0.85
    print("15% Discount Applied to Clothing")

df.head()
# Out:
# 10% Discount Applied to Electronics
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan       4383.0      2729            4852    1614        14065          NaN
# Feb       3302.1      3432            2649    2490        12240   -12.975471
# Mar       3697.2      3349            4290    4102        15849    29.485294
# Apr        967.5      3188            3564    1997         9824   -38.015017
# May       2129.4      2751            2924    1395         9436    -3.949511

# %%
# Part III: Visualizations (Matplotlib & Seaborn)

# %%
import matplotlib.pyplot as plt

# 1. Monthly Sales Trends (Line Plot)

plt.figure(figsize=(10,6))

for column in columns:
    plt.plot(df.index, df[column], marker='o', label=column)

plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)
plt.show()

# %%
# 2. Box Plot – Sales Distribution

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.boxplot(data=df[columns])
plt.title("Sales Distribution by Category")
plt.show()

# %%
# Q.2 For the array: array = np.array([[1, -2, 3],[-4, 5, -6]])

# %%
# i) Element-wise Absolute Value

array = np.array([[1, -2, 3],[-4, 5, -6]])
np.abs(array)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# ii) Percentiles

# Flattened
np.percentile(array.flatten(), [25, 50, 75])

# Column-wise
np.percentile(array, [25, 50, 75], axis=0)

# Row-wise
np.percentile(array, [25, 50, 75], axis=1)
# Out:
# array([[-0.5, -5. ],
#        [ 1. , -4. ],
#        [ 2. ,  0.5]])

# %%
# iii) Mean, Median, Std

# Flattened
print("Mean:", np.mean(array))
print("Median:", np.median(array))
print("Std:", np.std(array))

# Column-wise
print("Column Mean:", np.mean(array, axis=0))
print("Column Median:", np.median(array, axis=0))
print("Column Std:", np.std(array, axis=0))

# Row-wise
print("Row Mean:", np.mean(array, axis=1))
print("Row Median:", np.median(array, axis=1))
print("Row Std:", np.std(array, axis=1))
# Out:
# Mean: -0.5
# Median: -0.5
# Std: 3.8622100754188224
# Column Mean: [-1.5  1.5 -1.5]
# Column Median: [-1.5  1.5 -1.5]
# Column Std: [2.5 3.5 4.5]
# Row Mean: [ 0.66666667 -1.66666667]
# Row Median: [ 1. -4.]
# Row Std: [2.05480467 4.78423336]

# %%
# Q.3 For the array: a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0]).

a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])

print("Floor:", np.floor(a))
print("Ceiling:", np.ceil(a))
print("Truncated:", np.trunc(a))
print("Rounded:", np.round(a))
# Out:
# Floor: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded: [-2. -2. -0.  0.  2.  2.  3.]

# %%
# Q.4 WAP to swap two elements in a list in Python Using a Temporary Variable.

lst = [10, 20, 30, 40]

pos1 = 1
pos2 = 3

temp = lst[pos1]
lst[pos1] = lst[pos2]
lst[pos2] = temp

print("Swapped List:", lst)
# Out:
# Swapped List: [10, 40, 30, 20]

# %%
# Q.5 Write a Python program to swap two elements in a set by converting it to a list first.

s = {1, 2, 3, 4}

# Convert to list
lst = list(s)

pos1 = 0
pos2 = 2

# Swap
lst[pos1], lst[pos2] = lst[pos2], lst[pos1]

# Convert back to set
s = set(lst)

print("Swapped Set:", s)
# Out:
# Swapped Set: {1, 2, 3, 4}
